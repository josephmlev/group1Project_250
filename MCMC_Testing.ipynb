# %%
import numpy as np
import pandas as pd
import functions as funs
import model as mod
import sampler as samp
import matplotlib.pyplot as plt
import numpy.random as rand

# %%
myData = funs.dataObject('sys')

# %%
chain = samp.mcmc_sampler(myData,100)
print(chain)
# Out:
# [ 5.01470269e+01  3.12615831e-02  3.30399452e-02 -2.52908156e+01]
# accept
# [ 4.95931645e+01  1.13905642e-02 -7.50427906e-02 -2.52347342e+01]
# accept
# [ 4.99807576e+01 -2.02887651e-02  6.97283606e-03 -2.54462205e+01]
# accept
# [ 5.01934154e+01  4.53592867e-02 -3.93025567e-03 -2.52913609e+01]
# accept
# [ 4.96227833e+01  8.99292605e-03  6.79255548e-02 -2.49139318e+01]
# accept
# [ 4.98982754e+01 -7.84190970e-03 -1.02590586e-02 -2.47727053e+01]
# accept
# [ 4.98946985e+01 -2.32479799e-02  7.11005120e-02 -2.52434402e+01]
# accept
# [ 5.02585574e+01 -5.90351956e-03  4.08723483e-02 -2.49796766e+01]
# accept
# [ 5.00489798e+01 -2.06651831e-02  1.82893955e-02 -2.46212765e+01]
# accept
# [ 5.01026912e+01  3.07147631e-02  8.53031084e-02 -2.52135184e+01]
# accept
# [ 5.01174051e+01  5.80460585e-02  1.85915042e-02 -2.50199006e+01]
# accept
# [ 4.96330065e+01  1.53734801e-02  5.19334805e-02 -2.45341860e+01]
# accept
# [ 4.99078529e+01  2.13348454e-02 -2.03371400e-02 -2.46295244e+01]
# ...

# %%
plt.plot(chain[:,0])

# %%
plt.plot(chain[:,1])

# %%
plt.plot(chain[:,2])

# %%
plt.plot(chain[:,3])
